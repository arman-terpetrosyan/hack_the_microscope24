# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My\ Drive/GraphEM/
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive/GraphEM

# %%
for i,f in enumerate(["image encoding data", "atom percent data", "eds spectra"]):
  print(i, f)
# Out:
# 0 image encoding data
# 1 atom percent data
# 2 eds spectra

# %%
# !pip install louvain
# %run louvain_community_detection.py --path_chip_db "data.h5" --path_clustering_output "" --c 0.8
# Out:
# ...
# /gdrive/My Drive/GraphEM/louvain_community_detection.py:28: DeprecationWarning: This package has been superseded by the `leidenalg` package and will no longer be maintained. Please upgrade to the `leidenalg` package.
#   import louvain
# Loading chip database from data.h5
# Number of rows:  24
# Number of columns:  24
# Clustering individual modalities using cutoff=0.8
# /gdrive/My Drive/GraphEM/louvain_community_detection.py:62: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   chip_df = chip_df.replace({"chip ID": d}).sort_values(by=['chip ID']).replace({"chip ID": inv_d})
# Ensembling modality pairs
# Clustering output saved to .

# %%
# %run plot_results.py --path_chip_db "data.h5" --path_clustering_output "./results.csv" --modality "haadf"
# Out:
# Loading clustering results
# ...chip database: data.h5
# ...clustering output: ./results.csv
# Plotting overlay of clustering using haadf modality
# Overlay plot saved to overlay.png.

# %%
# %run agglomerative_clustering.py --path_chip_db "data.h5" --path_clustering_output "./results2.csv" --c 4
# Out:
# Loading chip database from data.h5
# Clustering individual modalities using n_clusters=4
# Ensembling modality pairs
# Clustering output saved to ./results2.csv.

# %%
# %run plot_results.py --path_chip_db "data.h5" --path_clustering_output "./results2.csv" --modality "haadf"
# Out:
# Loading clustering results
# ...chip database: data.h5
# ...clustering output: ./results2.csv
# Plotting overlay of clustering using haadf modality
# Overlay plot saved to overlay.png.
